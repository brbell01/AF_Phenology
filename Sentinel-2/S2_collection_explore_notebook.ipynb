# %% [markdown]
# <a href="https://colab.research.google.com/github/brbell01/AF_Phenology/blob/main/Sentinel-2/S2_collection_explore_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geemap

# %%
import ee
import folium
import geemap.foliumap as geemap

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=kUE5B4hz4G7KKGasLUM--Ay-jE0gNYiDimLRQE8F8k4&code_challenge_method=S256
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWiEEEgYwTVfytNSBUoItl_M_ulKYm1rL2WFX-0lNOnmCttqW8JTQtE
#
# Successfully saved authorization token.

# %%
# !git clone https://github.com/brbell01/AF_Phenology.git

# %%
geemap.ee_search()
# Out:
# Tree(nodes=(Node(name='ee.Algorithms', nodes=(Node(icon='file', name='ee.Algorithms.CannyEdgeDetector'), Node(…

# %%
MATA_ESCURA_PARK = ee.FeatureCollection("projects/af-phenology/assets/Parks/PN_Mata_Escura")
hectares = ee.FeatureCollection("projects/af-phenology/assets/Parks/Mata_Escura_hectares")
s2Clouds = ee.ImageCollection("COPERNICUS/S2_CLOUD_PROBABILITY")
S2 = ee.ImageCollection("COPERNICUS/S2");
cloudprob = s2Clouds.first()

# %% [markdown]
# Set up the Map

# %%
# Define a method for displaying Earth Engine image tiles to folium map.
def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
    tiles = map_id_dict['tile_fetcher'].url_format,
    attr = 'Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    name = name,
    overlay = True,
    control = True
  ).add_to(self)

# %%
geemap.Map.add_ee_layer = add_ee_layer
Map = folium.Map(basemap='HYBRID', location=[-17, -41.5], zoom_start=9)
Map.add_child(folium.LayerControl())
#Map.centerObject(MATA_ESCURA_PARK,11)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-28d8f3b5327d> in <module>()
#       2 Map = folium.Map(basemap='HYBRID', location=[-17, -41.5], zoom_start=9)
#       3 Map.add_child(folium.LayerControl())
# ----> 4 Map.centerObject(MATA_ESCURA_PARK,11)
#
# AttributeError: 'Map' object has no attribute 'centerObject'

# %%
helpers = require('users/brbell01/AF_Phenology:Helpers');
constants = require('users/brbell01/AF_Phenology:Constants');
hectares = helpers.randomFeaturesByPercentage(geometry, 1)
